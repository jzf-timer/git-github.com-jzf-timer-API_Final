# %% [markdown]
# ## 百度手写字体识别

# %%
import urllib, urllib.request, sys
import requests
import ssl
import json
import pprint
import base64
# client_id 为官网获取的AK， client_secret 为官网获取的SK
def get_file_content(filePath):
    with open(filePath, 'rb') as fp:
        return fp.read()
host = 'https://aip.baidubce.com/oauth/2.0/token?grant_type=client_credentials&client_id=ABDsQ1Lmq7hsDd3LhfIrExP6&client_secret=RCc8uX5zIeFNyyaGRh7k5SX0uNKdhRV1'
request = urllib.request.Request(host)
request.add_header('Content-Type', 'application/json; charset=UTF-8')
response = urllib.request.urlopen(request)
content = response.read()
# if (content):
#     print(content)
access_token = eval(content)["access_token"]
access_token
# access_token = "24.2f675d03474d01f013372af8ff2a3ba7.2592000.1574426829.282335-17604736"
# image = get_file_content(r'C:\Users\Administrator\Desktop\ces.jpg')
url = "https://aip.baidubce.com/rest/2.0/ocr/v1/handwriting?access_token="+access_token
# print(image)
with open(r'C:\Users\Administrator\Desktop\手写字体识别\ocr1.jpg', 'rb') as f:
    base64_data = base64.b64encode(f.read())
    a = base64_data.decode()
    
with open(r'C:\Users\Administrator\Desktop\手写字体识别\ocr.jpg', 'rb') as f:
    base64_data = base64.b64encode(f.read())
    b = base64_data.decode()
# ur = urllib.parse.quote(image)
# print(type(ur))

data={"image":a}

data1={ "image":b}

headers = {'content-type': 'application/x-www-form-urlencoded'
           }
# encode_data = json.dumps(data).encode('utf-8')
# print(encode_data)
r = requests.post(url, data = data, headers=headers)
result = r.json()
pprint.pprint(result)
r1 = requests.post(url, data = data1, headers=headers)
result = r1.json()
pprint.pprint(result)
# Out:
# {'log_id': 1326833002369772022,
#  'words_result': [{'location': {'height': 283,
#                                 'left': 982,
#                                 'top': 588,
#                                 'width': 1336},
#                    'words': '手写字体识别'},
#                   {'location': {'height': 474,
#                                 'left': 925,
#                                 'top': 866,
#                                 'width': 2482},
#                    'words': '我不想熬夜——网新必备'}],
#  'words_result_num': 2}
# {'log_id': 6123219736944639062,
#  'words_result': [{'location': {'height': 28,
#                                 'left': 38,
#                                 'top': 2,
#                                 'width': 427},
#                    'words': 'Theteribleearthguakeandthefollouingtsunami'},
#                   {'location': {'height': 29,
#                                 'left': 18,
#                                 'top': 25,
#                                 'width': 420},
#                    'words': 'havecausedsomanypeoplesinjuriesanddeoths'},
#                   {'location': {'height': 21,
#                                 'left': 18,
#                                 'top': 50,
#                                 'width': 459},
#                    'words': 'Besdesmanycitizensbecomehomeless.Wechinesefeel'},
#                   {'location': {'height': 29,
#                                 'left': 17,
#                                 'top': 74,
#                                 'width': 441},
#                    'words': 'greotlysorryforthepainsyouaresuffering.AndI'},
#                   {'location': {'height': 24,
#                                 'left': 18,
#                                 'top': 102,
#                                 'width': 418},
#                    'words': 'dohopeyoucanovercomethosegreatdifficuties.'},
#                   {'location': {'height': 22,
#                                 'left': 32,
#                                 'top': 125,
#                                 'width': 456},
#                    'words': 'Pleoserememberlapanisntalone.Peoplealloverthe'},
#                   {'location': {'height': 28,
#                                 'left': 8,
#                                 'top': 150,
#                                 'width': 409},
#                    'words': 'worldarelendinghandstotheareasstruckby'},
#                   {'location': {'height': 17,
#                                 'left': 423,
#                                 'top': 152,
#                                 'width': 66},
#                    'words': 'tsunam'},
#                   {'location': {'height': 27,
#                                 'left': 12,
#                                 'top': 175,
#                                 'width': 456},
#                    'words': 'andearthquoke.Nowthatthedisasterhashappened.'},
#                   {'location': {'height': 28,
#                                 'left': 7,
#                                 'top': 202,
#                                 'width': 466},
#                    'words': 'weshouldfaceitbraveyandrebuildthehomsthus'},
#                   {'location': {'height': 23,
#                                 'left': 12,
#                                 'top': 228,
#                                 'width': 467},
#                    'words': 'creatingastrongercountry.Tomorrowisanotherday.'},
#                   {'location': {'height': 24,
#                                 'left': 12,
#                                 'top': 255,
#                                 'width': 242},
#                    'words': 'Althethnswillbebetter'}],
#  'words_result_num': 12}

# %% [markdown]
# ### 返回中文结果完全正确，格式亦完全正确，英文识别结果问题很大，断句不准，英文达不到使用要求。
