# %% [markdown]
# ## 讯飞语音评测

# %%
#!/usr/bin/python
# -*- coding: UTF-8 -*-
import base64
import hashlib
import json
import time
import requests
def main():
    x_appid = '5df5101f'
    api_key = '6f4275409e109ffe7d44adb0383d99ef'
    curTime = str(int(time.time()))
    url = 'http://api.xfyun.cn/v1/service/v1/ise'
    text = "不管我的梦想能否成为事实"
    AUDIO_PATH = r'C:\Users\Administrator\Desktop\评测试题及音频样例\中文试题及音频样例\cn_sentence.wav'
    with open(AUDIO_PATH, 'rb') as f:
        file_content = f.read()
    base64_audio = base64.b64encode(file_content)
    body = {'audio': base64_audio, 'text': text}
    param = json.dumps({"aue": "raw", "result_level": "entirety", "language": "zh_cn", "category": "read_sentence"})
    paramBase64 = str(base64.b64encode(param.encode('utf-8')), 'utf-8')
    m2 = hashlib.md5()
    m2.update((api_key + curTime + paramBase64).encode('utf-8'))
    checkSum = m2.hexdigest()
    x_header = {
                'X-Appid': x_appid,
                'X-CurTime': curTime,
                'X-Param': paramBase64,
                'X-CheckSum': checkSum,
                'Content-Type': 'application/x-www-form-urlencoded; charset=utf-8',
                }
    req = requests.post(url, data=body, headers=x_header)
    result = req.content.decode('utf-8')
    print(result)
    return



if __name__ == '__main__':
    main()
# Out:
# {"code": "0", "desc": "success", "sid": "wse0016d2ec@dxf2131157dcdb6f2300", "data": {"read_sentence": {"rec_tree": {"read_sentence": {"beg_pos": "0", "content": "不管我的梦想能否成为事实", "end_pos": "380", "time_len": "380", "sentence": {"word": [{"beg_pos": "0", "content": "不", "end_pos": "74", "symbol": "bu4", "time_len": "74", "syll": [{"beg_pos": "0", "content": "sil", "dp_message": "0", "end_pos": "44", "rec_node_type": "sil", "time_len": "44", "phone": {"beg_pos": "0", "content": "sil", "dp_message": "0", "end_pos": "44", "rec_node_type": "sil", "time_len": "44"}}, {"rec_node_type": "paper", "symbol": "bu4", "time_len": "30", "phone": [{"time_len": "14", "beg_pos": "44", "content": "b", "dp_message": "0", "end_pos": "58", "is_yun": "0", "perr_level_msg": "0", "rec_node_type": "paper"}, {"beg_pos": "58", "content": "u", "dp_message": "0", "end_pos": "74", "is_yun": "1", "mono_tone": "TONE4", "time_len": "16", "perr_level_msg": "0", "rec_node_type": "paper"}], "beg_pos": "44", "content": "不", "dp_message": "0", "end_pos": "74"}]}, {"end_pos": "100", "symbol": "guan2", "time_len": "26", "syll": {"rec_node_type": "paper", "symbol": "guan2", "time_len": "26", "phone": [{"time_len": "10", "beg_pos": "74", "content": "g", "dp_message": "0", "end_pos": "84", "is_yun": "0", "perr_level_msg": "0", "rec_node_type": "paper"}, {"beg_pos": "84", "content": "uan", "is_yun": "1", "mono_tone": "TONE2", "rec_node_type": "paper", "dp_message": "0", "end_pos": "100", "perr_level_msg": "0", "time_len": "16"}], "beg_pos": "74", "content": "管", "dp_message": "0", "end_pos": "100"}, "beg_pos": "74", "content": "管"}, {"end_pos": "128", "symbol": "wo3", "time_len": "28", "syll": {"end_pos": "128", "rec_node_type": "paper", "symbol": "wo3", "time_len": "28", "phone": [{"content": "_u", "dp_message": "0", "end_pos": "114", "is_yun": "0", "perr_level_msg": "0", "rec_node_type": "paper", "time_len": "14", "beg_pos": "100"}, {"beg_pos": "114", "content": "uo", "dp_message": "0", "end_pos": "128", "is_yun": "1", "mono_tone": "TONE3", "perr_level_msg": "0", "rec_node_type": "paper", "time_len": "14"}], "beg_pos": "100", "content": "我", "dp_message": "0"}, "beg_pos": "100", "content": "我"}, {"end_pos": "147", "symbol": "de5", "time_len": "19", "syll": {"end_pos": "147", "rec_node_type": "paper", "symbol": "de0", "time_len": "19", "phone": [{"rec_node_type": "paper", "time_len": "10", "beg_pos": "128", "content": "d", "dp_message": "0", "end_pos": "138", "is_yun": "0", "perr_level_msg": "0"}, {"dp_message": "0", "is_yun": "1", "perr_level_msg": "0", "rec_node_type": "paper", "beg_pos": "138", "content": "e", "end_pos": "147", "mono_tone": "TONE0", "time_len": "9"}], "beg_pos": "128", "content": "的", "dp_message": "0"}, "beg_pos": "128", "content": "的"}, {"beg_pos": "147", "content": "梦", "end_pos": "174", "symbol": "meng4", "time_len": "27", "syll": {"beg_pos": "147", "content": "梦", "dp_message": "0", "end_pos": "174", "rec_node_type": "paper", "symbol": "meng4", "time_len": "27", "phone": [{"beg_pos": "147", "content": "m", "dp_message": "0", "end_pos": "161", "is_yun": "0", "perr_level_msg": "0", "rec_node_type": "paper", "time_len": "14"}, {"beg_pos": "161", "is_yun": "1", "mono_tone": "TONE4", "perr_level_msg": "0", "rec_node_type": "paper", "time_len": "13", "content": "eng", "dp_message": "0", "end_pos": "174"}]}}, {"beg_pos": "174", "content": "想", "end_pos": "206", "symbol": "xiang3", "time_len": "32", "syll": {"rec_node_type": "paper", "symbol": "xiang3", "time_len": "32", "phone": [{"time_len": "17", "beg_pos": "174", "content": "x", "dp_message": "0", "end_pos": "191", "is_yun": "0", "perr_level_msg": "0", "rec_node_type": "paper"}, {"rec_node_type": "paper", "time_len": "15", "beg_pos": "191", "content": "iang", "dp_message": "0", "end_pos": "206", "is_yun": "1", "mono_tone": "TONE3", "perr_level_msg": "0"}], "beg_pos": "174", "content": "想", "dp_message": "0", "end_pos": "206"}}, {"time_len": "28", "syll": {"phone": [{"rec_node_type": "paper", "time_le ...
